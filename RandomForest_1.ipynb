# %% [markdown]
# <a href="https://colab.research.google.com/github/yasiruKodikara/machine-learning-lessons/blob/main/RandomForest_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# !wget = https://raw.githubusercontent.com/dineshpiyasamara/machine_learning_tutorial/refs/heads/master/Decision%20Tree%2C%20Random%20Forest/kyphosis.csv
# Out:
# --2025-08-19 03:54:57--  http://=/
# Resolving = (=)... failed: Name or service not known.
# wget: unable to resolve host address ‘=’
# --2025-08-19 03:54:57--  https://raw.githubusercontent.com/dineshpiyasamara/machine_learning_tutorial/refs/heads/master/Decision%20Tree%2C%20Random%20Forest/kyphosis.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1430 (1.4K) [text/plain]
# Saving to: ‘kyphosis.csv’
#
# kyphosis.csv        100%[===================>]   1.40K  --.-KB/s    in 0s
#
# 2025-08-19 03:54:58 (26.0 MB/s) - ‘kyphosis.csv’ saved [1430/1430]
#
# FINISHED --2025-08-19 03:54:58--
# Total wall clock time: 0.2s
# Downloaded: 1 files, 1.4K in 0s (26.0 MB/s)

# %%
data  = pd.read_csv('kyphosis.csv')

# %%
data.head(5)
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
data.shape
# Out:
# (81, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
X = data.drop('Kyphosis',axis=1)
y = data['Kyphosis']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=101)

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred = model.predict(X_test)

# %%
pred,y_test
# Out:
# (array(['absent', 'present', 'present', 'absent', 'absent', 'absent',
#         'absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#         'absent', 'absent', 'absent', 'absent', 'absent'], dtype=object),
#  33     absent
#  61    present
#  21    present
#  32     absent
#  20     absent
#  13     absent
#  52    present
#  25     absent
#  22    present
#  27     absent
#  30     absent
#  2     present
#  67     absent
#  16     absent
#  69     absent
#  6      absent
#  53     absent
#  Name: Kyphosis, dtype: object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred,y_test)
# Out:
# 0.8235294117647058

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(pred,y_test)
# Out:
# array([[12,  3],
#        [ 0,  2]])
