# %% [markdown]
# <a href="https://colab.research.google.com/github/yasiruKodikara/machine-learning-lessons/blob/main/LogisticRegressionImplementingPython_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget = https://raw.githubusercontent.com/dineshpiyasamara/machine_learning_tutorial/refs/heads/master/Logistic%20Regression/sample.csv
# Out:
# --2025-08-01 17:41:59--  http://=/
# Resolving = (=)... failed: Name or service not known.
# wget: unable to resolve host address ‘=’
# --2025-08-01 17:41:59--  https://raw.githubusercontent.com/dineshpiyasamara/machine_learning_tutorial/refs/heads/master/Logistic%20Regression/sample.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 141 [text/plain]
# Saving to: ‘sample.csv’
#
# sample.csv          100%[===================>]     141  --.-KB/s    in 0s
#
# 2025-08-01 17:42:00 (2.39 MB/s) - ‘sample.csv’ saved [141/141]
#
# FINISHED --2025-08-01 17:42:00--
# Total wall clock time: 0.2s
# Downloaded: 1 files, 141 in 0s (2.39 MB/s)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/sample.csv')
data.head(5)
# Out:
#     age  job
# 21   13    0
# 22   51    1
# 23   43    1
# 24   23    0
# 25   31    1

# %%
plt.scatter(data['age'],data['job'])

# %%
X = data[["age"]]
y = data["job"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 0, 0, 0, 1, 0])

# %%
y_test
# Out:
# 2     1
# 20    0
# 14    1
# 17    0
# 5     0
# 11    0
# Name: job, dtype: int64

# %%
model.score(X_test,y_test)
# Out:
# 0.6666666666666666

# %% [markdown]
# # Make predictions

# %%
age = [[24]]
model.predict(age)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
ages = np.array([12,23,34,45])
model.predict(ages.reshape(-1, 1))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0, 0, 1, 1])
